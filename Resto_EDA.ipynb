# %%
import pandas as pd

# %%
data=pd.read_csv('RestoInfo_cleaned.csv')

# %%
data
# Out:
#       Unnamed: 0     ID                                     name online_order  \
# 0              0  46019                   Unique Brew Cafe Resto           No
# 1              1  28849                           Jayanthi Sagar           No
# 2              2  19855             Rock Stone Ice Cream Factory          Yes
# 3              3  35188                    Punjabi by Nature 2.0           No
# 4              4   7070                        Rayalaseema Chefs          Yes
# ...          ...    ...                                      ...          ...
# 2063        2064   8778                                  Zeeshan          Yes
# 2064        2065  18086                        Zaica Dine & Wine          Yes
# 2065        2066  46112  Murphy's Brewhouse - The Paul Bangalore           No
# 2066        2067  10808                                  Cee Yem           No
# 2067        2068  28875                        Cauvery Fast Food           No
#
# ...
